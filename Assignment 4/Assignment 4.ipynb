# %% [markdown]
# # Question 1: Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\mysel\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: trio~=0.17 in c:\users\mysel\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\mysel\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\mysel\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\mysel\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: idna in c:\users\mysel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: async-generator>=1.9 in c:\users\mysel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\mysel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in c:\users\mysel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\mysel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\mysel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\mysel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\mysel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\mysel\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\mysel\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\mysel\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\mysel\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)
time.sleep(2)
# Out:
# C:\Users\mysel\AppData\Local\Temp\ipykernel_8704\340483077.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\chromedriver.exe')

# %%
# Empty list for scraping data
Rank =[]
Name =[]
Artist =[]
Upload_date=[]
Views=[]

# %%
# Extracting Rank Via X path
try:
    rank=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('NA')
except StaleElementReferenceException:
    Rank.append('NA')
    
# Extracting Name Via X path
try:
    name=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
    for i in name:
        Name.append(i.text)
except NoSuchElementExceptionhElementException:
    Name.append('NA')
except StaleElementReferenceException:
    Name.append('NA')
    
# Extracting Artist Name Via Xpath
try:
    artist=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artist:
        Artist.append(i.text)
except NoSuchElementExceptionhElementException:
    Artist.append('NA')
except StaleElementReferenceException:
    Artist.append('NA')

# Extracting Upload date Via Xpath
try:
    upload_date=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in upload_date:
        Upload_date.append(i.text)
except NoSuchElementExceptionhElementException:
    Upload_date.append('NA')
except StaleElementReferenceException:
    Upload_date.append('NA') 

# Extracting Views via Xpath
try:
    views=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in views:
        Views.append(i.text)
except NoSuchElementExceptionhElementException:
    Views.append('NA')
except StaleElementReferenceException:
    Views.append('NA')

# %%
# Dataframe for scrap data
Wiki_YT=pd.DataFrame({'Rank':Rank,'Video Name':Name,'Uploader':Artist,'Views (in Billons)':Views,'Upload Date':Upload_date})
print('\033[1m'+'Most Viewed Video on YouTube from Wikipedia :'+'\033[0m')
Wiki_YT
# Out:
# Most Viewed Video on YouTube from Wikipedia :
#    Rank                                       Video Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                          "Wheels on the Bus"[24]
# 8    9.                                "Uptown Funk"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                     "Axel F"[35]
# 15  16.                                       "Roar"[36]
# 16  17.                             "Counting Stars"[37]
# 17  18.                                      "Sorry"[38]
# 18  19.                          "Thinking Out Loud"[39]
# 19  20.                        "Baa Baa Black Sheep"[40]
# 20  21.           "Waka Waka (This Time for Africa)"[41]
# 21  22.                                 "Dark Horse"[42]
# 22  23.                                      "Faded"[43]
# 23  24.                                 "Let Her Go"[44]
# 24  25.                                    "Perfect"[45]
# 25  26.                             "Girls Like You"[46]
# 26  27.                             "Lakdi Ki Kathi"[47]
# 27  28.                                   "Bailando"[48]
# 28  29.                                    "Lean On"[49]
# 29  30.          "Humpty the train on a fruits ride"[50]
#
#                                          Uploader Views (in Billons)  \
# 0     Pinkfong Baby Shark - Kids' Songs & Stories              12.55
# 1                                      Luis Fonsi               8.11
# 2                                     LooLoo Kids               6.66
# 3                      Cocomelon – Nursery Rhymes               6.08
# 4                                      Ed Sheeran               5.95
# 5                                     Wiz Khalifa               5.82
# 6                                       ChuChu TV               5.22
# 7                      Cocomelon – Nursery Rhymes               5.04
# 8                                     Mark Ronson               4.87
# 9                                     Miroshka TV               4.86
# 10                                            Psy               4.73
# 11                                     Get Movies               4.54
# 12                                      El Chombo               4.28
# 13                                       Maroon 5               3.84
# 14                                     Crazy Frog               3.82
# 15                                     Katy Perry               3.76
# 16                                    OneRepublic               3.75
# 17                                  Justin Bieber               3.64
# 18                                     Ed Sheeran               3.57
# 19                     Cocomelon – Nursery Rhymes               3.56
# 20                                        Shakira               3.52
# 21                                     Katy Perry               3.48
# 22                                    Alan Walker               3.42
# 23                                      Passenger               3.40
# 24                                     Ed Sheeran               3.40
# 25                                       Maroon 5               3.39
# 26                                   Jingle Toons               3.37
# 27                               Enrique Iglesias               3.35
# 28                                    Major Lazer               3.35
# 29  Kiddiestv Hindi – Nursery Rhymes & Kids Songs               3.34
#
#           Upload Date
# 0       June 17, 2016
# 1    January 12, 2017
# 2     October 8, 2016
# 3         May 2, 2018
# 4    January 30, 2017
# 5       April 6, 2015
# 6       March 6, 2014
# 7        May 24, 2018
# 8   November 19, 2014
# 9   February 27, 2018
# 10      July 15, 2012
# 11   January 31, 2012
# 12      April 5, 2018
# 13   January 14, 2015
# 14      June 16, 2009
# 15  September 5, 2013
# 16       May 31, 2013
# 17   October 22, 2015
# 18    October 7, 2014
# 19      June 25, 2018
# 20       June 4, 2010
# 21  February 20, 2014
# 22   December 3, 2015
# 23      July 25, 2012
# 24   November 9, 2017
# 25       May 31, 2018
# 26      June 14, 2018
# 27     April 11, 2014
# 28     March 22, 2015
# 29   January 26, 2018

# %% [markdown]
# # Scrape the details teamIndia’sinternationalfixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1stODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\chromedriver.exe')
time.sleep(1)

# Opening webpage
url='https://www.bcci.tv/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\mysel\AppData\Local\Temp\ipykernel_8704\511637724.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\chromedriver.exe')

# %%
# Opening fixtures webpage through browser
fixtures=driver.find_element(By.XPATH,"/html/body/div[5]/div/div[1]/div/ul/li[1]/a")
try:
    fixtures.click()
except ElementNotInteractableException:
    driver.get(fixtures.get_attribute('href'))

# %%
#No fixer available on site

# %% [markdown]
# # Scrape the details of State-wise GDP ofIndia fromstatisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)- at current prices
# D) GSDP(19-20)- at current prices
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://www.statisticstimes.com/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\mysel\AppData\Local\Temp\ipykernel_8704\3343773433.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\chromedriver.exe')

# %%
# Creating Empty lists
Rank =[]
State =[]
GDSP_19_20=[]
GDSP_18_19 =[]
Share =[]
GDP =[]

# %%
# Clicking on India under ecomony section
India=driver.find_element(By.XPATH,'//div[@class="dropdown"][2]/div/a[3]')
try:
    India.click()
except ElementNotInteractableException:
    driver.get(India.get_attribute('href'))
    
time.sleep(2)

# Clicking Indian State GDP
state = driver.find_element(By.XPATH,'//ul[@style="list-style-type:none;margin-left:20px;"]/li[1]/a')
try:
    state.click()
except ElementNotInteractableException:
    driver.get(state.get_attribute('href'))
time.sleep(2)

# %%
# Extracting Rank via Xpath
try:
    rank=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[1]')
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('NA')
    
# Extracting state name via Xpath
try:
    state=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[2]')
    for i in state:
        State.append(i.text)
except NoSuchElementException:
    State.append('NA')
    
# Extracting GDSP 19-20 via Xpath
try:
    gdsp_19_20=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[3]')
    for i in gdsp_19_20:
        GDSP_19_20.append(i.text)
except NoSuchElementException:
    GDSP_19_20.append('NA')
    
# Extracting GDSP 18-19 via Xpath
try:
    gdsp_18_19=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[4]')
    for i in gdsp_18_19:
        GDSP_18_19.append(i.text)
except NoSuchElementException:
    GDSP_18_19.append('NA')
    
# Extracting share in billons via Xpath
try:
    share=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[5]')
    for i in share:
        Share.append(i.text)
except NoSuchElementException:
    Share.append('NA')

# Extracting GDP via Xpath
try:
    gdp=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[6]')
    for i in gdp:
        GDP.append(i.text)
except NoSuchElementException:
    GDP.append('NA')

# %%
# Dataframe for scrap data
Statewise_GDP=pd.DataFrame({'Rank':Rank,'State':State,'GDSP 19-20':GDSP_19_20,'GDSP 18-19':GDSP_18_19,
                            'Share':Share,'GDP (in Billions)':GDP})
print('\033[1m'+'State-wise GDP of India :'+'\033[0m')
Statewise_GDP
# Out:
# State-wise GDP of India :
#    Rank                      State GDSP 19-20 GDSP 18-19   Share  \
# 0     1                Maharashtra          -  2,632,792  13.94%
# 1     2                 Tamil Nadu  1,845,853  1,630,208   8.63%
# 2     3              Uttar Pradesh  1,687,818  1,584,764   8.39%
# 3     4                    Gujarat          -  1,502,899   7.96%
# 4     5                  Karnataka  1,631,977  1,493,127   7.91%
# 5     6                West Bengal  1,253,832  1,089,898   5.77%
# 6     7                  Rajasthan  1,020,989    942,586   4.99%
# 7     8             Andhra Pradesh    972,782    862,957   4.57%
# 8     9                  Telangana    969,604    861,031   4.56%
# 9    10             Madhya Pradesh    906,672    809,592   4.29%
# 10   11                     Kerala          -    781,653   4.14%
# 11   12                      Delhi    856,112    774,870   4.10%
# 12   13                    Haryana    831,610    734,163   3.89%
# 13   14                      Bihar    611,804    530,363   2.81%
# 14   15                     Punjab    574,760    526,376   2.79%
# 15   16                     Odisha    521,275    487,805   2.58%
# 16   17                      Assam          -    315,881   1.67%
# 17   18               Chhattisgarh    329,180    304,063   1.61%
# 18   19                  Jharkhand    328,598    297,204   1.57%
# 19   20                Uttarakhand          -    245,895   1.30%
# 20   21            Jammu & Kashmir          -    155,956   0.83%
# 21   22           Himachal Pradesh    165,472    153,845   0.81%
# 22   23                        Goa     80,449     73,170   0.39%
# 23   24                    Tripura     55,984     49,845   0.26%
# 24   25                 Chandigarh          -     42,114   0.22%
# 25   26                 Puducherry     38,253     34,433   0.18%
# 26   27                  Meghalaya     36,572     33,481   0.18%
# 27   28                     Sikkim     32,496     28,723   0.15%
# 28   29                    Manipur     31,790     27,870   0.15%
# 29   30                   Nagaland          -     27,283   0.14%
# 30   31          Arunachal Pradesh          -     24,603   0.13%
# 31   32                    Mizoram     26,503     22,287   0.12%
# 32   33  Andaman & Nicobar Islands          -          -       -
#
#    GDP (in Billions)
# 0            399.921
# 1            247.629
# 2            240.726
# 3            228.290
# 4            226.806
# 5            165.556
# 6            143.179
# 7            131.083
# 8            130.791
# 9            122.977
# 10           118.733
# 11           117.703
# 12           111.519
# 13            80.562
# 14            79.957
# 15            74.098
# 16            47.982
# 17            46.187
# 18            45.145
# 19            37.351
# 20            23.690
# 21            23.369
# 22            11.115
# 23             7.571
# 24             6.397
# 25             5.230
# 26             5.086
# 27             4.363
# 28             4.233
# 29             4.144
# 30             3.737
# 31             3.385
# 32                 -

# %% [markdown]
# # Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\chromedriver.exe')
time.sleep(1)

# Opening webpage
url='https://github.com/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\mysel\AppData\Local\Temp\ipykernel_11720\2079683264.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\chromedriver.exe')

# %%
# Clicking on trending option
trending=driver.find_element(By.XPATH,'//ul[@class="list-style-none mb-3"][2]/li[3]/a')
try:
    trending.click()
except ElementNotInteractableException:
    driver.get(trending.get_attribute('href'))
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 # Clicking on trending option
# ----> 2 trending=driver.find_element(By.XPATH,'//ul[@class="list-style-none mb-3"][2]/li[3]/a')
#       3 try:
#       4     trending.click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     827     by = By.CSS_SELECTOR
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//ul[@class="list-style-none mb-3"][2]/li[3]/a"}
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x002EDCE3]
# 	(No symbol) [0x002839D1]
# 	(No symbol) [0x00194DA8]
# 	(No symbol) [0x001C019F]
# 	(No symbol) [0x001C03AB]
# 	(No symbol) [0x001EEE62]
# 	(No symbol) [0x001DAF14]
# 	(No symbol) [0x001ED57C]
# 	(No symbol) [0x001DACC6]
# 	(No symbol) [0x001B6F68]
# 	(No symbol) [0x001B80CD]
# 	GetHandleVerifier [0x00563832+2506274]
# 	GetHandleVerifier [0x00599794+2727300]
# 	GetHandleVerifier [0x0059E36C+2746716]
# 	GetHandleVerifier [0x00396690+617600]
# 	(No symbol) [0x0028C712]
# 	(No symbol) [0x00291FF8]
# 	(No symbol) [0x002920DB]
# 	(No symbol) [0x0029C63B]
# 	BaseThreadInitThunk [0x75B900F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BB7BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BB7B8E+238]
# 	(No symbol) [0x00000000]

# %%
# Creating Empty list for Scraping Data
Title=[]
Description=[]
Count =[]
Language =[]

# %%
# Scraping repositories URL
URL= []
link=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]/a')
for i in link:
    URL.append(i.get_attribute('href'))

# %%
len(URL)
# Out:
# 0

# %%
# Scraping Repositority Title
try:
    title=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
    for i in title:
        Title.append(i.text)
except NoSuchElementException:
    Title.append('NA')

# %%
len(Title)
# Out:
# 0

# %%
from tqdm import tqdm
for i in tqdm(URL):
    driver.get(i)
    time.sleep(5)
    # Scraping Description
    try:
        description=driver.find_element(By.XPATH,'/html/body/div[4]/div/main/div[2]/div/div/div[2]/div[2]/div/div[1]/div/p')
        Description.append(description.text)
    except NoSuchElementException:
        Description.append('NA')
    
    # Scraping Contributor count
    try:
        count=driver.find_element(By.XPATH,"//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        Count.append(count.text)
    except NoSuchElementException:
        Count.append('NA')
    
    # Scraping Language
    L =[]
    try:
        lang=driver.find_elements(By.XPATH,"//li[@class='d-inline']//a//span[1]")
        if lang:
            for j in lang:
                L.append(j.text)
        else:
            L.append('NA')
        Language.append(L)
    except NoSuchElementException:
        Language.append('NA')
# Out:
# 0it [00:00, ?it/s]

# %%
Github=pd.DataFrame({'Title':Title,'Description':Description,
                'Contributors_count':Count,'Language_used':Language})
print('\033[1m'+'GitHub Trending Repository :'+'\033[0m')
Github
# Out:
# GitHub Trending Repository :
# Empty DataFrame
# Columns: [Title, Description, Contributors_count, Language_used]
# Index: []

# %% [markdown]
# # Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\chromedriver.exe')
time.sleep(1)

# Opening webpage
url='https://www.billboard.com/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\mysel\AppData\Local\Temp\ipykernel_11720\4105560302.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\chromedriver.exe')

# %%
# Creating Empty List
Song =[]
Artist =[]
Last_Week_rank=[]
Peak_rank =[]
Weeks =[]

# %%
# Clicking on hot 100 option
search = driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[4]/div/div[1]/div[1]/button/svg")
search.click()
hot_100 = driver.find_element(By.XPATH,"/html/body/div[3]/div[9]/div/div/div/ul/li[1]/ul/li[2]/a")
hot_100.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 # Clicking on hot 100 option
# ----> 2 search = driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[4]/div/div[1]/div[1]/button/svg")
#       3 search.click()
#       4 hot_100 = driver.find_element(By.XPATH,"/html/body/div[3]/div[9]/div/div/div/ul/li[1]/ul/li[2]/a")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     827     by = By.CSS_SELECTOR
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[3]/header/div/div[4]/div/div[1]/div[1]/button/svg"}
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x002EDCE3]
# 	(No symbol) [0x002839D1]
# 	(No symbol) [0x00194DA8]
# 	(No symbol) [0x001C019F]
# 	(No symbol) [0x001C03AB]
# 	(No symbol) [0x001EEE62]
# 	(No symbol) [0x001DAF14]
# 	(No symbol) [0x001ED57C]
# 	(No symbol) [0x001DACC6]
# 	(No symbol) [0x001B6F68]
# 	(No symbol) [0x001B80CD]
# 	GetHandleVerifier [0x00563832+2506274]
# 	GetHandleVerifier [0x00599794+2727300]
# 	GetHandleVerifier [0x0059E36C+2746716]
# 	GetHandleVerifier [0x00396690+617600]
# 	(No symbol) [0x0028C712]
# 	(No symbol) [0x00291FF8]
# 	(No symbol) [0x002920DB]
# 	(No symbol) [0x0029C63B]
# 	BaseThreadInitThunk [0x75B900F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BB7BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BB7B8E+238]
# 	(No symbol) [0x00000000]

# %%
# Scraping Song Name
try:
    song=driver.find_elements(By.XPATH,'//span[@class="chart-element__information"]/span[1]')
    for i in song:
        Song.append(i.text)
except NoSuchElementException:
    Song.append('NA')
    
# Scraping Song Artist Name
try:
    artist=driver.find_elements(By.XPATH,'//span[@class="chart-element__information"]/span[2]')
    for i in artist:
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append('NA')
    
# Scraping Song last week rank
try:
    last_rank=driver.find_elements(By.XPATH,'//span[@class="chart-element__information"]/span[2]')
    for i in last_rank:
        Last_Week_rank.append(i.text)
except NoSuchElementException:
    Last_Week_rank.append('NA')

# Scraping Song peak rank
try:
    peak=driver.find_elements(By.XPATH,'//span[@class="chart-element__information"]/span[2]')
    for i in peak:
        Peak_rank.append(i.text)
except NoSuchElementException:
    Peak_rank.append('NA')

# Scraping Song Artist Name
try:
    weeks=driver.find_elements(By.XPATH,'//span[@class="chart-element__information"]/span[2]')
    for i in weeks:
        Weeks.append(i.text)
except NoSuchElementException:
    Weeks.append('NA')

# %%
Billboard=pd.DataFrame({'Song_Name':Song,
                'Artist_Name':Artist,
                'Last_week_rank':Last_Week_rank,
                'Peak':Peak_rank,
                'Weeks_on_chart':Weeks})
print('\033[1m'+'Billboard Hot 100 Songs :'+'\033[0m')
Billboard
# Out:
# Billboard Hot 100 Songs :
# Empty DataFrame
# Columns: [Song_Name, Artist_Name, Last_week_rank, Peak, Weeks_on_chart]
# Index: []

# %% [markdown]
# # Scrape the details of Highest sellingnovels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\mysel\AppData\Local\Temp\ipykernel_11720\2856894683.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\chromedriver.exe')

# %%
# Creating Empty Lists
Book =[]
Author =[]
Volumes_sold =[]
Publisher =[]
Genre =[]

# %%
# Scraping Book name
try:
    book=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
    for i in book:
        Book.append(i.text)
except NoSuchElementException:
    Book.append('NA')
    
# Scraping Book author's via Xpath
try:
    author=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')
    for i in author:
        Author.append(i.text)
except NoSuchElementException:
    Author.append('NA')
    
# Scraping Volumes sold via Xpath
try:
    sold=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
    for i in sold:
        Volumes_sold.append(i.text)
except NoSuchElementException:
    Volumes_sold.append('NA')
    
# Scraping publisher via xPath
try:
    publisher=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')
    for i in publisher:
        Publisher.append(i.text)
except NoSuchElementException:
    Publisher.append('NA')
    
# Scraping Genre via Xpath
try:
    genre=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
    for i in genre:
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append('NA')

# %%
#creating dataframe
Top_Books=pd.DataFrame({"Book Title":Book,
                "Author Name":Author,
                'Volumes sold':Volumes_sold,
                'Publisher':Publisher,
                'Genre':Genre})
print('\033[1m'+'Best Selling Books of All Time List by The Guardian  :'+'\033[0m')
Top_Books
# Out:
# Best Selling Books of All Time List by The Guardian  :
#                                            Book Title       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# 0     5,094,805       Transworld  Crime, Thriller & Adventure
# 1     4,475,152       Bloomsbury           Children's Fiction
# 2     4,200,654       Bloomsbury           Children's Fiction
# 3     4,179,479       Bloomsbury           Children's Fiction
# 4     3,758,936     Random House              Romance & Sagas
# ..          ...              ...                          ...
# 95      807,311     Random House   General & Literary Fiction
# 96      794,201          Penguin        Food & Drink: General
# 97      792,187  Scholastic Ltd.          Young Adult Fiction
# 98      791,507            Orion           Biography: General
# 99      791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# # Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\mysel\AppData\Local\Temp\ipykernel_11720\2113668778.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\chromedriver.exe')

# %%
# Creating Empty List
Name =[]
Year_Span=[]
Genre =[]
Run_Time =[]
Ratings =[]
Votes =[]

# %%
# Scraping Name via Xpath
try:
    name=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a")
    for i in name:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('NA')

# Scraping Year span via Xpath
try:
    year=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/span[2]")
    for i in year:
        Year_Span.append(i.text)
except NoSuchElementException:
    Year_Span.append('NA')
    
# Scraping Genre via Xpath
try:
    genre=driver.find_elements(By.XPATH,"//span[@class='genre']")
    for i in genre:
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append('NA')
    
# Scraping RunTime via Xpath
try:
    runtime=driver.find_elements(By.XPATH,"//span[@class='runtime']")
    for i in runtime:
        Run_Time.append(i.text)
except NoSuchElementException:
    Run_Time.append('NA')

# Scraping Ratings via Xpath
try:
    ratings=driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']/span[2]")
    for i in ratings:
        Ratings.append(i.text)
except NoSuchElementException:
    Ratings.append('NA')

# Scraping Votes via Xpath
try:
    votes=driver.find_elements(By.XPATH,"//span[@name='nv']")
    for i in votes:
        Votes.append(i.text)
except NoSuchElementException:
    Votes.append('NA')

# %%
#creating dataframe
IMDB_TV=pd.DataFrame({"Name":Name,
                "Year Span":Year_Span,
                "Genre":Genre,
                "Run Time":Run_Time,
                "Ratings":Ratings,
                "Votes":Votes})
print('\033[1m'+'Top 100 most watched tv shows of all time IMDB :'+'\033[0m')
IMDB_TV
# Out:
# Top 100 most watched tv shows of all time IMDB :
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2024)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,142,336
# 1    51 min     8.7  1,226,490
# 2    44 min     8.1  1,017,095
# 3    60 min     7.5    299,539
# 4    43 min     7.6    258,384
# ..      ...     ...        ...
# 95   42 min     7.4     51,116
# 96   50 min     7.8     63,129
# 97   42 min     8.1    205,476
# 98   45 min       7     42,637
# 99  572 min     8.6    254,351
#
# [100 rows x 6 columns]

# %% [markdown]
# # Details of Datasetsfrom UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\chromedriver.exe')
time.sleep(1)

# Opening webpage
url='https://archive.ics.uci.edu/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\mysel\AppData\Local\Temp\ipykernel_11720\2968150010.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\chromedriver.exe')

# %%
# Clicking on all datasets links
dataset=driver.find_element(By.XPATH,"//a[@href='datasets.php']")
dataset.click()
time.sleep(1)

# %%
# Creating empty lists
Dataset =[]
Data_Type =[]
Task =[]
Attribute_Type =[]
No_of_Instances =[]
No_of_Attribute =[]
Year =[]

# %%
# Scraping DataSet Name via Xpath
from tqdm import tqdm
try:
    dataset=driver.find_elements(By.XPATH,"//p[@class='normal']/b/a")
    for i in tqdm(dataset):
        Dataset.append(i.text)
        time.sleep(0.15)
except NoSuchElementException:
    Dataset.append('NA')
    
# Scraping Data Type via Xpath
try:
    Type=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]')
    for i in Type[1:]:
        Data_Type.append(i.text)
except NoSuchElementException:
    Data_Type.append('NA')
    
# Scraping Task via Xpath
try:
    task=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]')
    for i in task[1:]:
        Task.append(i.text)
except NoSuchElementException:
    Task.append('NA')
    
# Scraping Attribute_Type via Xpath
try:
    attribute_Type=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]')
    for i in attribute_Type[1:]:
        Attribute_Type.append(i.text)
except NoSuchElementException:
    Attribute_Type.append('NA')
    
# Scraping No_of_Instances via Xpath
try:
    no_of_Instances=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]')
    for i in no_of_Instances[1:]:
        No_of_Instances.append(i.text)
except NoSuchElementException:
    No_of_Instances.append('NA')

# Scraping No_of_Attribute via Xpath
try:
    no_of_Attribute=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]')
    for i in no_of_Attribute[1:]:
        No_of_Attribute.append(i.text)
except NoSuchElementException:
    No_of_Attribute.append('NA')
    
# Scraping Year via Xpath
try:
    year=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]')
    for i in year[1:]:
        Year.append(i.text)
except NoSuchElementException:
    Year.append('NA')
# Out:
# 100%|██████████| 622/622 [02:14<00:00,  4.62it/s]

# %%
len(Dataset),len(Data_Type),len(Task),len(Attribute_Type),len(No_of_Instances),len(Year)
# Out:
# (622, 622, 622, 622, 622, 622)

# %%
# Creating Data Frame for UCI Dataset
UCI_Dataset=pd.DataFrame({'DataSet Title':Dataset,
                'Data Type':Data_Type,
                'Task':Task,
                'Attribute Type':Attribute_Type,
                'No of Instances':No_of_Instances,
                'No of Attribute':No_of_Attribute,
                'Year':Year})
print('\033[1m'+' UCI Machine Learning Dataset:'+'\033[0m')
UCI_Dataset
# Out:
#  UCI Machine Learning Dataset:
#                                          DataSet Title  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data Type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# 4                 Multivariate        Classification
# ..                          ...                   ...
# 617               Multivariate        Classification
# 618               Multivariate        Classification
# 619                                   Classification
# 620  Multivariate, Time-Series        Classification
# 621                 Univariate            Regression
#
#                   Attribute Type No of Instances No of Attribute   Year
# 0    Categorical, Integer, Real            4177               8   1995
# 1          Categorical, Integer           48842              14   1996
# 2    Categorical, Integer, Real             798              38
# 3                   Categorical           37711             294   1998
# 4    Categorical, Integer, Real             452             279   1998
# ..                           ...             ...             ...    ...
# 617               Integer, Real           75840             525   2020
# 618               Integer, Real             400              50   2020
# 619                                        1014               7   2020
# 620                        Real           10129              16   2021
# 621                        Real            4000               2   2021
#
# [622 rows x 7 columns]
